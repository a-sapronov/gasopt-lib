# %%
# %matplotlib inline

import pandas as pd
import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import sys
sys.path.append("../gasopt/") # Adds higher directory to python modules path.

# %%
from data_load import tses_forecast_data_process

# %%
G = tses_forecast_data_process('../../gasopt/examples/test_data/Исх. данные ЦЭС.xlsx')

# %%
G.head()
# Out:
#                        gas
# datetime
# 2019-01-01 00:00:00  44.98
# 2019-01-01 01:00:00  41.18
# 2019-01-01 02:00:00  42.16
# 2019-01-01 03:00:00  40.75
# 2019-01-01 04:00:00  41.95

# %%
from generator_interface import generator_forecast

# %%
from data_load import build_tses_dataset

# %%
T = build_tses_dataset(G, 24, 24)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700

# %%
F = generator_forecast(G, horizon=24)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# VanillaRNN(
#   (rnn): RNN(24, 10, batch_first=True)
#   (fc): Linear(in_features=10, out_features=24, bias=True)
# )
# /home/sapronov/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                                  Statespace Model Results
# ...
# Dep. Variable:                                  y   No. Observations:                  672
# Model:             SARIMAX(2, 1, 1)x(1, 1, 0, 24)   Log Likelihood               -1735.820
# Date:                            Fri, 22 May 2020   AIC                           3481.640
# Time:                                    15:01:42   BIC                           3504.002
# Sample:                                         0   HQIC                          3490.316
#                                             - 672
# ...

# %%
F
# Out:
#          FFNN        RNN    SARIMAX       ARCH
# 0   48.342755  52.521643  48.385061  48.382918
# 1   48.307056  47.670303  48.389064  48.386921
# 2   48.585999  51.075761  48.393066  48.390923
# 3   48.720957  59.212300  48.397068  48.394925
# 4   48.891368  43.482040  48.401071  48.398928
# 5   48.881643  41.438272  48.405073  48.402930
# 6   48.949398  46.869104  48.409075  48.406932
# 7   49.097532  64.685690  48.413078  48.410935
# 8   48.763858  53.284078  48.417080  48.414937
# 9   49.046230  35.800878  48.421082  48.418939
# 10  48.827420  48.605727  48.425085  48.422942
# 11  48.616112  51.781380  48.429087  48.426944
# 12  48.502669  45.718800  48.433089  48.430946
# 13  48.502797  56.212526  48.437092  48.434949
# 14  48.434613  43.846574  48.441094  48.438951
# 15  48.684529  44.024817  48.445096  48.442953
# 16  48.291131  53.291751  48.449099  48.446956
# 17  48.331379  45.196062  48.453101  48.450958
# 18  48.478477  42.258462  48.457103  48.454960
# ...
