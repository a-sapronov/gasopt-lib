# %%
# %matplotlib inline

import pandas as pd
import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import sys
sys.path.append("../gasopt/") # Adds higher directory to python modules path.

# %%
from data_load import furn_forecast_data_process

# %%
G = furn_forecast_data_process('../../mmk/data/gas-expense-10.19.xlsx')

# %%
G.head()
# Out:
#               dt_hour             1             2             3            4
# 0 2019-10-01 00:00:00  16775.333333  15930.833333  16521.166667    20.666667
# 1 2019-10-01 01:00:00  14845.500000  13519.666667  14620.166667  2003.000000
# 2 2019-10-01 02:00:00  13759.500000  13059.000000  13968.166667  2014.333333
# 3 2019-10-01 03:00:00  14503.666667  13382.666667  14211.833333  1833.166667
# 4 2019-10-01 04:00:00  13843.833333  13107.000000  14001.666667  3502.333333

# %%
from furnance_interface import furnace_forecast

# %%
from data_load import build_furn_dataset

# %%
F = furnace_forecast(G, horizon=24, furn_id=1)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# VanillaRNN(
#   (rnn): RNN(24, 10, batch_first=True)
#   (fc): Linear(in_features=10, out_features=24, bias=True)
# )
#                                  Statespace Model Results
# ...
# Dep. Variable:                                  y   No. Observations:                  672
# Model:             SARIMAX(2, 1, 1)x(1, 1, 0, 24)   Log Likelihood               -5890.578
# Date:                            Wed, 20 May 2020   AIC                          11791.155
# Time:                                    16:26:44   BIC                          11813.517
# Sample:                                         0   HQIC                         11799.831
#                                             - 672
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
F
# Out:
#             FFNN           RNN       SARIMAX          ARCH
# 0   11824.761745  12023.141075  11960.926106  11961.092799
# 1   11800.599374  11157.934874  11947.746568  11947.913261
# 2   11738.343324  11684.524558  11934.567030  11934.733723
# 3   11829.450820  13228.838746  11921.387492  11921.554185
# 4   11729.762189  12174.213717  11908.207954  11908.374647
# 5   11770.681635  12013.617780  11895.028416  11895.195109
# 6   11666.452881  11338.125742  11881.848878  11882.015571
# 7   11849.959048  12620.647448  11868.669340  11868.836033
# 8   11603.534204  13535.094378  11855.489802  11855.656495
# 9   11784.907326  11275.164677  11842.310264  11842.476957
# 10  11687.516025  10911.820777  11829.130726  11829.297419
# 11  11664.704640  12369.675561  11815.951188  11816.117881
# 12  11727.667394  10796.973274  11802.771650  11802.938343
# 13  11745.791632  11578.476510  11789.592112  11789.758805
# 14  11763.734762  16167.039514  11776.412574  11776.579267
# ...
